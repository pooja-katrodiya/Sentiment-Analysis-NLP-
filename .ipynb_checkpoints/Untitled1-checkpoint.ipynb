# %%
pip install rembg
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from rembg import remove
from PIL import Image
# Out:
# C:\Users\kruta\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\kruta\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
# C:\Users\kruta\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# C:\Users\kruta\anaconda3\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
from rembg import remove
from PIL import Image

input_path = r'C:\Users\kruta\Downloads\me.jpg'

output_path = r'C:\Users\kruta\Downloads\output.png'

# Open the input image
input_image = Image.open(input_path)

# Remove the background from the input image
output_image = remove(input_image)

output_image.save(output_path)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))

# Input image
plt.subplot(1, 2, 1)
plt.imshow(input_image)
plt.title('Input Image')
plt.axis('off')

# Output image
plt.subplot(1, 2, 2)
plt.imshow(output_image)
plt.title('Output Image')
plt.axis('off')

plt.show()

# %%
input_path = r'C:\Users\kruta\Downloads\img.jpg'
output_path = 'output.jpg'

# Open the image
input_image = Image.open(input_path)

# Convert the image to RGB mode
input_image = input_image.convert("RGB")

# Assuming remove function does something to the input image
output_image = remove(input_image)

# Save the output image
output_image.save(output_path)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\PIL\JpegImagePlugin.py in _save(im, fp, filename)
#     629     try:
# --> 630         rawmode = RAWMODE[im.mode]
#     631     except KeyError as e:
#
# KeyError: 'RGBA'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30680\4080058465.py in <module>
#      12
#      13 # Save the output image
# ---> 14 output_image.save(output_path)
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2318
#    2319         try:
# -> 2320             save_handler(self, fp, filename)
#    2321         except Exception:
#    2322             if open_fp:
#
# ~\anaconda3\lib\site-packages\PIL\JpegImagePlugin.py in _save(im, fp, filename)
# ...

# %%
from PIL import Image

input_path = r'C:\Users\kruta\Downloads\img.jpg'
output_path = 'output.jpg'

input_image = Image.open(input_path)

# Convert the image to RGB mode
input_image = input_image.convert("RGB")

# Assuming remove function does something to the input image
output_image = remove(input_image)

output_image.save(output_path)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\PIL\JpegImagePlugin.py in _save(im, fp, filename)
#     629     try:
# --> 630         rawmode = RAWMODE[im.mode]
#     631     except KeyError as e:
#
# KeyError: 'RGBA'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30680\3170551099.py in <module>
#      12 output_image = remove(input_image)
#      13
# ---> 14 output_image.save(output_path)
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2318
#    2319         try:
# -> 2320             save_handler(self, fp, filename)
#    2321         except Exception:
#    2322             if open_fp:
#
# ~\anaconda3\lib\site-packages\PIL\JpegImagePlugin.py in _save(im, fp, filename)
# ...

# %%
input_path = r'C:\Users\kruta\Downloads\img.jpg'
output_path = 'output.jpg'

input = Image.open(input_path)
output = remove(input)
output.save(output_path)


# im = Image.open("audacious.png")
# rgb_im = im.convert('RGB')
# rgb_im.save('audacious.jpg')
# print(input)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\PIL\JpegImagePlugin.py in _save(im, fp, filename)
#     629     try:
# --> 630         rawmode = RAWMODE[im.mode]
#     631     except KeyError as e:
#
# KeyError: 'RGBA'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30680\3805647040.py in <module>
#       4 input = Image.open(input_path)
#       5 output = remove(input)
# ----> 6 output.save(output_path)
#       7
#       8
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2318
#    2319         try:
# -> 2320             save_handler(self, fp, filename)
#    2321         except Exception:
#    2322             if open_fp:
#
# ...
